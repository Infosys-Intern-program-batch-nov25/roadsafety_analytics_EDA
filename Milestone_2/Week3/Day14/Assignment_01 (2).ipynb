# %% [markdown]
# ### Assignment-1

# %% [markdown]
# 1. How many unique values are there in categorical columns like `City`, `State`, and `Weather_Condition`? Which category is the most frequent in each?

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/RoadSafety_Nov25/data/raw/US_Accidents_March23.csv')

print(f" Dataset loaded successfully!")
print(f"Shape: {df.shape}")
print(f"Columns: {df.columns.tolist()[:5]}...")

columns = ['City', 'State', 'Weather_Condition']

for col in columns:
    print(f"\nColumn: {col}")
    print("Unique values:", df[col].nunique())
    print("Most frequent:", df[col].value_counts().idxmax())
    print("Count:", df[col].value_counts().max())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  Dataset loaded successfully!
# Shape: (7728394, 46)
# Columns: ['ID', 'Source', 'Severity', 'Start_Time', 'End_Time']...
#
# Column: City
# Unique values: 13678
# Most frequent: Miami
# Count: 186917
#
# Column: State
# Unique values: 49
# Most frequent: CA
# Count: 1741433
#
# Column: Weather_Condition
# Unique values: 144
# Most frequent: Fair
# Count: 2560802

# %% [markdown]
# 2. Calculate the percentage of missing values in each column and list columns with more than 5% missing data.

# %%
missing_percent = (df.isnull().mean() * 100).round(2)
print("Missing Value Percentage in Each Column:\n")
print(missing_percent)
cols_over_5 = missing_percent[missing_percent > 5]

print("\nColumns with more than 5% missing data:\n")
print(cols_over_5)
# Out:
# Missing Value Percentage in Each Column:
#
# ID                        0.00
# Source                    0.00
# Severity                  0.00
# Start_Time                0.00
# End_Time                  0.00
# Start_Lat                 0.00
# Start_Lng                 0.00
# End_Lat                  44.03
# End_Lng                  44.03
# Distance(mi)              0.00
# Description               0.00
# Street                    0.14
# City                      0.00
# County                    0.00
# State                     0.00
# Zipcode                   0.02
# Country                   0.00
# Timezone                  0.10
# Airport_Code              0.29
# Weather_Timestamp         1.56
# Temperature(F)            2.12
# Wind_Chill(F)            25.87
# Humidity(%)               2.25
# Pressure(in)              1.82
# Visibility(mi)            2.29
# Wind_Direction            2.27
# Wind_Speed(mph)           7.39
# Precipitation(in)        28.51
# Weather_Condition         2.24
# Amenity                   0.00
# Bump                      0.00
# Crossing                  0.00
# Give_Way                  0.00
# Junction                  0.00
# No_Exit                   0.00
# Railway                   0.00
# Roundabout                0.00
# Station                   0.00
# Stop                      0.00
# Traffic_Calming           0.00
# Traffic_Signal            0.00
# Turning_Loop              0.00
# Sunrise_Sunset            0.30
# Civil_Twilight            0.30
# Nautical_Twilight         0.30
# Astronomical_Twilight     0.30
# dtype: float64
#
# Columns with more than 5% missing data:
#
# End_Lat              44.03
# End_Lng              44.03
# Wind_Chill(F)        25.87
# Wind_Speed(mph)       7.39
# Precipitation(in)    28.51
# dtype: float64

# %% [markdown]
# 3. Convert `Start_Time` and `End_Time` columns to datetime objects. Find the range (earliest and latest) of accident start times in the dataset.

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'], format='mixed', errors='coerce')
df['End_Time'] = pd.to_datetime(df['End_Time'], format='mixed', errors='coerce')
earliest = df['Start_Time'].min()
latest = df['Start_Time'].max()

print("Earliest accident start time:", earliest)
print("Latest accident start time:", latest)
print(f"\nTime range: {earliest.date()} to {latest.date()}")

null_start = df['Start_Time'].isnull().sum()
null_end = df['End_Time'].isnull().sum()

print(f"\nRows with unparseable Start_Time: {null_start}")
print(f"Rows with unparseable End_Time: {null_end}")
# Out:
# Earliest accident start time: 2016-01-14 20:18:33
# Latest accident start time: 2023-03-31 23:30:00
#
# Time range: 2016-01-14 to 2023-03-31
#
# Rows with unparseable Start_Time: 0
# Rows with unparseable End_Time: 0

# %% [markdown]
# 4. Identify any duplicate records in the dataset based on all columns. How many duplicates exist and how will you handle them?

# %%
duplicates = df.duplicated().sum()
print("Number of duplicate records:", duplicates)
print(f"Original dataset shape: {df.shape}")
df = df.drop_duplicates(keep='first')

print(f"Dataset shape after removing duplicates: {df.shape}")

print(f"\nHandling approach: Removed all duplicate records, keeping the first occurrence.")
# Out:
# Number of duplicate records: 0
# Original dataset shape: (7728394, 46)
# Dataset shape after removing duplicates: (7728394, 46)
#
# Handling approach: Removed all duplicate records, keeping the first occurrence.

# %% [markdown]
# 5. Explore the distribution of accident severity (Severity column). What percentage of accidents belong to each severity level? Visualize this distribution with a pie chart.

# %%
import matplotlib.pyplot as plt
severity_percent = (df['Severity'].value_counts(normalize=True) * 100).round(2)

print("Percentage of accidents by severity level:\n")
print(severity_percent)
print(f"\nTotal accidents analyzed: {len(df)}")
plt.figure(figsize=(8, 8))
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']
plt.pie(
    severity_percent,
    labels=[f'Severity {i}' for i in severity_percent.index],
    autopct='%1.1f%%',
    startangle=90,
    colors=colors[:len(severity_percent)]
)
plt.title("Accident Severity Distribution", fontsize=14, fontweight='bold')
plt.axis('equal')
plt.show()
# Out:
# Percentage of accidents by severity level:
#
# Severity
# 2    79.67
# 3    16.81
# 4     2.65
# 1     0.87
# Name: proportion, dtype: float64
#
# Total accidents analyzed: 7728394
