# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dataset_path = '/content/drive/MyDrive/Colab Notebooks/US_Accidents_March23.csv'
us_accidents_df = pd.read_csv(dataset_path)

# %%
us_accidents_df.sample(10)
# Out:
#                 ID   Source  Severity                     Start_Time  \
# 422690    A-422703  Source2         2            2017-05-01 06:51:26
# 6431090  A-6478565  Source1         2  2021-02-09 13:57:06.000000000
# 2252977  A-2262844  Source2         2            2019-02-04 11:16:10
# 663962    A-673642  Source2         2            2022-03-17 03:09:32
# 198098    A-198105  Source2         2            2016-12-28 11:56:57
# 4202702  A-4234395  Source1         2            2022-05-03 06:18:00
# 4697496  A-4733146  Source1         2  2022-05-19 15:48:12.000000000
# 6932037  A-6981341  Source1         2            2020-05-26 09:00:42
# 7190892  A-7240253  Source1         2            2020-01-27 08:02:00
# 3320327  A-3330210  Source2         2            2017-09-25 08:14:45
#
#                               End_Time  Start_Lat   Start_Lng    End_Lat  \
# 422690             2017-05-01 07:21:17  40.557312  -74.205269        NaN
# 6431090  2021-02-09 21:20:06.000000000  47.033489 -114.327367  47.031539
# 2252977            2019-02-04 11:45:58  30.470249  -97.789909        NaN
# 663962             2022-03-17 04:07:08  30.136740  -85.747231        NaN
# 198098             2016-12-28 12:26:36  41.790951  -73.552986        NaN
# 4202702            2022-05-03 09:48:49  26.508197  -80.074593  26.467077
# 4697496  2022-05-19 17:58:35.000000000  35.082501  -85.057602  35.081863
# 6932037            2020-05-26 09:45:42  25.571720  -80.376420  25.568110
# 7190892            2020-01-27 08:34:30  34.105610 -118.254440  34.105570
# 3320327            2017-09-25 08:44:36  39.899914  -85.994598        NaN
#
#             End_Lng  Distance(mi)  ... Roundabout Station   Stop  \
# 422690          NaN         0.010  ...      False   False  False
# 6431090 -114.318617         0.434  ...      False   False  False
# 2252977         NaN         0.000  ...      False   False  False
# 663962          NaN         0.000  ...      False   False  False
# 198098          NaN         0.010  ...      False   False  False
# 4202702  -80.089343         2.984  ...      False   False  False
# 4697496  -85.058945         0.088  ...      False   False  False
# 6932037  -80.379960         0.333  ...      False   False  False
# 7190892 -118.254390         0.004  ...      False   False  False
# 3320327         NaN         0.000  ...      False   False  False
#
#         Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 422690            False          False        False            Day
# 6431090           False          False        False            Day
# 2252977           False           True        False            Day
# 663962            False          False        False          Night
# 198098            False          False        False            Day
# 4202702           False          False        False          Night
# 4697496           False          False        False            Day
# 6932037           False           True        False            Day
# 7190892           False          False        False            Day
# 3320327           False           True        False            Day
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 422690             Day               Day                   Day
# 6431090            Day               Day                   Day
# 2252977            Day               Day                   Day
# 663962           Night             Night                 Night
# 198098             Day               Day                   Day
# 4202702            Day               Day                   Day
# 4697496            Day               Day                   Day
# 6932037            Day               Day                   Day
# 7190892            Day               Day                   Day
# 3320327            Day               Day                   Day
#
# [10 rows x 46 columns]

# %%
us_accidents_df.isnull()
# Out:
#             ID  Source  Severity  Start_Time  End_Time  Start_Lat  Start_Lng  \
# 0        False   False     False       False     False      False      False
# 1        False   False     False       False     False      False      False
# 2        False   False     False       False     False      False      False
# 3        False   False     False       False     False      False      False
# 4        False   False     False       False     False      False      False
# ...        ...     ...       ...         ...       ...        ...        ...
# 7728389  False   False     False       False     False      False      False
# 7728390  False   False     False       False     False      False      False
# 7728391  False   False     False       False     False      False      False
# 7728392  False   False     False       False     False      False      False
# 7728393  False   False     False       False     False      False      False
#
#          End_Lat  End_Lng  Distance(mi)  ...  Roundabout  Station   Stop  \
# 0           True     True         False  ...       False    False  False
# 1           True     True         False  ...       False    False  False
# 2           True     True         False  ...       False    False  False
# 3           True     True         False  ...       False    False  False
# 4           True     True         False  ...       False    False  False
# ...          ...      ...           ...  ...         ...      ...    ...
# 7728389    False    False         False  ...       False    False  False
# 7728390    False    False         False  ...       False    False  False
# 7728391    False    False         False  ...       False    False  False
# 7728392    False    False         False  ...       False    False  False
# 7728393    False    False         False  ...       False    False  False
#
#          Traffic_Calming  Traffic_Signal  Turning_Loop  Sunrise_Sunset  \
# 0                  False           False         False           False
# 1                  False           False         False           False
# 2                  False           False         False           False
# 3                  False           False         False           False
# 4                  False           False         False           False
# ...                  ...             ...           ...             ...
# 7728389            False           False         False           False
# 7728390            False           False         False           False
# 7728391            False           False         False           False
# 7728392            False           False         False           False
# 7728393            False           False         False           False
#
#          Civil_Twilight  Nautical_Twilight  Astronomical_Twilight
# 0                 False              False                  False
# 1                 False              False                  False
# 2                 False              False                  False
# 3                 False              False                  False
# 4                 False              False                  False
# ...                 ...                ...                    ...
# 7728389           False              False                  False
# 7728390           False              False                  False
# 7728391           False              False                  False
# 7728392           False              False                  False
# 7728393           False              False                  False
#
# [7728394 rows x 46 columns]

# %%
us_accidents_df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# Weather_Condition         173459
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset             23246
# Civil_Twilight             23246
# Nautical_Twilight          23246
# Astronomical_Twilight      23246
# dtype: int64

# %%
us_accidents_df.drop(['End_Lat', 'End_Lng'], axis=1, inplace=True)

# %%
temp_df = us_accidents_df[['Wind_Speed(mph)', 'Precipitation(in)']][:1000000]
temp_df.head()
# Out:
#    Wind_Speed(mph)  Precipitation(in)
# 0              NaN               0.02
# 1              NaN               0.00
# 2              3.5                NaN
# 3              4.6                NaN
# 4              3.5                NaN

# %%
import pandas as pd
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer

# Step 1: Randomly sample 100,000 rows from the dataset
sample_df = temp_df.sample(n=100000, random_state=42)

# Step 2: Perform regression imputation on the sample using IterativeImputer
reg_imputer = IterativeImputer(random_state=42)
sample_imputed = reg_imputer.fit_transform(sample_df)
sample_imputed_df = pd.DataFrame(sample_imputed, columns=sample_df.columns)

# Step 3: This sample_imputed_df is your imputed subset
print(sample_imputed_df.head())
# Out:
#    Wind_Speed(mph)  Precipitation(in)
# 0         13.00000           0.000000
# 1         11.50000           0.018010
# 2         10.00000           0.000000
# 3         10.40000           0.020000
# 4          7.76949           0.014144
