# %% [markdown]
# ### Assignment-1

# %% [markdown]
# ### 1. How many unique values are there in categorical columns like `City`, `State`, and `Weather_Condition`? Which category is the most frequent in each?

# %%
import pandas as pd
import os

# Load your dataset
file_path = 'US_Accidents_March23.csv'

if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please upload the dataset using the instructions in the text cell above (cell ID: f329f4eb) and then re-run this cell.")
else:
    df = pd.read_csv(file_path)  # Update path as needed

    # Columns to analyze
    columns = ['City', 'State', 'Weather_Condition']

    for col in columns:
        print(f"\nColumn: {col}")
        print("Unique values:", df[col].nunique())
        print("Most frequent:", df[col].value_counts().idxmax())
        print("Count:", df[col].value_counts().max())
# Out:
# Error: The file 'US_Accidents_March23.csv' was not found.
# Please upload the dataset using the instructions in the text cell above (cell ID: f329f4eb) and then re-run this cell.

# %%
import pandas as pd
import os

# Load your dataset
file_path = 'US_Accidents_March23.csv'

if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please upload the dataset using the instructions in the text cell above (cell ID: f329f4eb) and then re-run this cell.")
else:
    df = pd.read_csv(file_path)  # Update path as needed

    # Columns to analyze
    columns = ['City', 'State', 'Weather_Condition']

    for col in columns:
        print(f"\nColumn: {col}")
        print("Unique values:", df[col].nunique())
        print("Most frequent:", df[col].value_counts().idxmax())
        print("Count:", df[col].value_counts().max())
# Out:
# Error: The file 'US_Accidents_March23.csv' was not found.
# Please upload the dataset using the instructions in the text cell above (cell ID: f329f4eb) and then re-run this cell.

# %%
import pandas as pd
import os

# Load your dataset
file_path = 'US_Accidents_March23.csv'

if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please upload the dataset using the instructions in the text cell above (cell ID: f329f4eb) and then re-run this cell.")
else:
    df = pd.read_csv(file_path)  # Update path as needed

    # Columns to analyze
    columns = ['City', 'State', 'Weather_Condition']

    for col in columns:
        print(f"\nColumn: {col}")
        print("Unique values:", df[col].nunique())
        print("Most frequent:", df[col].value_counts().idxmax())
        print("Count:", df[col].value_counts().max())
# Out:
# Error: The file 'US_Accidents_March23.csv' was not found.
# Please upload the dataset using the instructions in the text cell above (cell ID: f329f4eb) and then re-run this cell.

# %% [markdown]
# ### Uploading the Dataset
#
# To resolve the `FileNotFoundError`, please upload the `US_Accidents_March23.csv` file to your Colab environment. You can do this by:
#
# 1. Clicking the 'Files' icon on the left sidebar (folder icon).
# 2. Clicking the 'Upload to session storage' icon (file with an arrow pointing up).
# 3. Selecting the `US_Accidents_March23.csv` file from your local machine and uploading it.
#
# Once the file is uploaded, you can re-run the code cells.

# %% [markdown]
# 2. Calculate the percentage of missing values in each column and list columns with more than 5% missing data.

# %%
import pandas as pd
import os

# Define the file path
file_path = 'US_Accidents_March23.csv'

# Check if the file exists before proceeding
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please upload the dataset using the instructions in cell f329f4eb and then re-run this cell.")
else:
    # Load your dataset if it exists
    df = pd.read_csv(file_path)

    # Calculate percentage of missing values for each column
    missing_percent = (df.isnull().mean() * 100).round(2)

    # Display all percentages
    print("Missing Value Percentage in Each Column:\n")
    print(missing_percent)

    # Columns with more than 5% missing data
    cols_over_5 = missing_percent[missing_percent > 5]

    print("\nColumns with more than 5% missing data:\n")
    print(cols_over_5)
# Out:
# Error: The file 'US_Accidents_March23.csv' was not found.
# Please upload the dataset using the instructions in cell f329f4eb and then re-run this cell.

# %% [markdown]
# 3. Convert `Start_Time` and `End_Time` columns to datetime objects. Find the range (earliest and latest) of accident start times in the dataset.

# %%
import pandas as pd
import os

# Define the file path
file_path = 'US_Accidents_March23.csv'

# Check if the file exists before proceeding
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please upload the dataset using the instructions in cell f329f4eb and then re-run this cell.")
else:
    # Load your dataset if it exists
    df = pd.read_csv(file_path)

    # Convert to datetime
    df['Start_Time'] = pd.to_datetime(df['Start_Time'])
    df['End_Time'] = pd.to_datetime(df['End_Time'])

    # Find earliest and latest accident start times
    earliest = df['Start_Time'].min()
    latest = df['Start_Time'].max()

    print("Earliest accident start time:", earliest)
    print("Latest accident start time:", latest)
# Out:
# Error: The file 'US_Accidents_March23.csv' was not found.
# Please upload the dataset using the instructions in cell f329f4eb and then re-run this cell.

# %% [markdown]
# 4. Identify any duplicate records in the dataset based on all columns. How many duplicates exist and how will you handle them?

# %%
import pandas as pd
import os

# Define the file path
file_path = 'US_Accidents_March23.csv'

# Check if the file exists before proceeding
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please upload the dataset using the instructions in cell f329f4eb and then re-run this cell.")
else:
    # Load your dataset if it exists
    df = pd.read_csv(file_path)

    # Count duplicate records
    duplicates = df.duplicated().sum()
    print("Number of duplicate records:", duplicates)

    # Remove duplicates
    df = df.drop_duplicates()
    print("Duplicates removed. New DataFrame shape:", df.shape)
# Out:
# Error: The file 'US_Accidents_March23.csv' was not found.
# Please upload the dataset using the instructions in cell f329f4eb and then re-run this cell.

# %% [markdown]
# 5. Explore the distribution of accident severity (Severity column). What percentage of accidents belong to each severity level? Visualize this distribution with a pie chart.

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# Define the file path
file_path = 'US_Accidents_March23.csv'

# Check if the file exists before proceeding
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
    print("Please upload the dataset using the instructions in cell f329f4eb and then re-run this cell.")
else:
    # Load your dataset if it exists
    df = pd.read_csv(file_path)

    # Percentage distribution of Severity
    severity_percent = (df['Severity'].value_counts(normalize=True) * 100).round(2)
    print("Percentage of accidents by severity level:\n")
    print(severity_percent)

    # Pie chart
    plt.figure(figsize=(6, 6))
    plt.pie(
        severity_percent,
        labels=severity_percent.index,
        autopct='%1.1f%%'
    )
    plt.title("Accident Severity Distribution")
    plt.show()
# Out:
# Error: The file 'US_Accidents_March23.csv' was not found.
# Please upload the dataset using the instructions in cell f329f4eb and then re-run this cell.
